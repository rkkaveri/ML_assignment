# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('weather.csv')
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 328 entries, 0 to 365
# Data columns (total 24 columns):
# Date             328 non-null object
# Location         328 non-null object
# MinTemp          328 non-null float64
# MaxTemp          328 non-null float64
# Rainfall         328 non-null float64
# Evaporation      328 non-null float64
# Sunshine         328 non-null float64
# WindGustDir      328 non-null object
# WindGustSpeed    328 non-null float64
# WindDir9am       328 non-null object
# WindDir3pm       328 non-null object
# WindSpeed9am     328 non-null float64
# WindSpeed3pm     328 non-null int64
# Humidity9am      328 non-null int64
# Humidity3pm      328 non-null int64
# Pressure9am      328 non-null float64
# Pressure3pm      328 non-null float64
# Cloud9am         328 non-null int64
# Cloud3pm         328 non-null int64
# Temp9am          328 non-null float64
# Temp3pm          328 non-null float64
# RainToday        328 non-null object
# ...

# %%
plt.hist(df['Rainfall']) #histogram
# Out:
# (array([325.,  21.,   6.,   3.,   8.,   1.,   1.,   0.,   0.,   1.]),
#  array([ 0.  ,  3.98,  7.96, 11.94, 15.92, 19.9 , 23.88, 27.86, 31.84,
#         35.82, 39.8 ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df['Sunshine'],hist=False,kde=True,rug=True)
# Out:
# /home/kritika/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /home/kritika/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.kdeplot(df['Rainfall'], shade=True, color="b")#line histogram

# %%
plt.plot(df['Evaporation'])

# %%
plt.scatter(df['MinTemp'],df['Temp9am']) #scatter plot two variables

# %%
plt.scatter(df['MinTemp'],df['MaxTemp'],alpha=0.4, edgecolors='g', linewidth=2) #bubble chart three variables

# %%
sns.lmplot(y='Pressure3pm',x='Pressure9am',data=df)

# %%
df = df.dropna()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=df['WindGustDir'],data=df)

# %%
sns.distplot(df['Pressure3pm'])
# Out:
# /home/kritika/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x='Rainfall',y='WindGustSpeed',hue='RainTomorrow',data=df)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='WindGustDir',y='MaxTemp',data=df,hue='RainTomorrow')

# %%
sns.jointplot(df['Temp9am'],df['Temp3pm'])
# Out:
# /home/kritika/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/kritika/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(df['Temp9am'], df['Temp3pm'],kind='kde',shade=True)

# %%
sns.jointplot(df['Temp9am'], df['Temp3pm'],kind='hex',color='b')
# Out:
# /home/kritika/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/kritika/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['Temp9am'], df['Temp3pm'])

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['Temp9am'], df['Temp3pm'],shade=True)
